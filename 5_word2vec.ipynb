# %% [markdown]
# # Deep Learning
# ## Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(path):
        path, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(path)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return path

filename = maybe_download('./data/text8/text8.zip', 'text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                    labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.374694
# Nearest to that: wailing, meteorologist, conditions, lightfoot, nothingness, retrospectively, cheerleading, decrement,
# Nearest to and: codebreaking, stadiums, lunch, eccentricity, journal, enough, evanston, commonest,
# Nearest to these: gz, massawa, socony, linnean, albuquerque, manaus, ethics, excuse,
# Nearest to he: shocked, commodus, round, equinoctial, sucre, aeronautical, earliest, ck,
# Nearest to th: paddington, akira, gated, discouraged, jalal, endosymbiont, ferguson, icy,
# Nearest to four: bentley, odors, manually, shopping, demoted, bofors, ciboney, sweetened,
# Nearest to may: batavia, keynesian, zyklon, dude, pacheco, clintons, maguey, confirmation,
# Nearest to called: expiration, whitehouse, namespaces, urbanized, ewes, medi, workplaces, digs,
# Nearest to most: dysphoria, gonzaga, directorate, rangers, smuggle, agricola, suffice, symbolics,
# Nearest to no: prologue, vessel, inquest, lector, wire, attila, deadheads, porter,
# Nearest to state: light, espn, multihull, astronomer, entropy, unparalleled, clues, celibate,
# Nearest to an: description, interpreted, shore, obituaries, fredericton, confirmation, refered, consolation,
# Nearest to for: alekhine, capitol, debuts, correlatives, reals, caracalla, soho, option,
# Nearest to they: suu, lesion, quintessential, aphex, joys, preponderance, vend, renegades,
# Nearest to will: errors, experiment, beating, hyksos, ing, semimajor, railway, engaging,
# Nearest to up: dubh, laymen, offended, catalogued, plagiarized, apparition, broz, genocide,
# Average loss at step 2000: 4.435186
# Average loss at step 4000: 3.893378
# Average loss at step 6000: 3.494316
# Average loss at step 8000: 3.705851
# Average loss at step 10000: 3.691537
# Nearest to that: which, impressionists, boka, however, ahab, pictures, hickok, firms,
# Nearest to and: or, of, s, with, when, marino, by, in,
# Nearest to these: some, dialysis, unrealistic, ambushed, beset, contact, nicolau, needs,
# Nearest to he: it, they, who, mousetrap, abendana, she, also, was,
# Nearest to th: paddington, akira, discouraged, gated, hingis, quote, eight, endosymbiont,
# Nearest to four: five, eight, six, three, nine, seven, zero, two,
# Nearest to may: can, must, will, prev, to, would, dispel, ennio,
# Nearest to called: expiration, namespaces, fullerenes, hrer, ewes, nic, remarked, biathlon,
# Nearest to most: dysphoria, more, rossini, forti, balto, chloe, unprecedented, geoid,
# Nearest to no: there, wire, cypriots, prologue, inquest, ballistics, landlords, pandora,
# Nearest to state: light, unparalleled, akc, espn, steamship, interpolant, xis, mongolia,
# Nearest to an: the, cliques, remarked, interpreted, homophobic, climbed, epoxy, deshima,
# Nearest to for: with, of, in, compositional, as, by, amphibians, hci,
# Nearest to they: it, he, renegades, there, suu, we, not, organisers,
# Nearest to will: may, obeys, would, can, could, prev, skate, aware,
# Nearest to up: plagiarized, sample, skirt, vanquish, mel, reputed, wheatstone, pavel,
# Average loss at step 12000: 3.619060
# Average loss at step 14000: 3.621581
# Average loss at step 16000: 3.562134
# Average loss at step 18000: 3.569565
# Average loss at step 20000: 3.448236
# Nearest to that: which, this, however, but, repeaters, what, schechter, it,
# Nearest to and: or, but, moluccas, corgi, scrutiny, longshanks, micros, balaenoptera,
# Nearest to these: some, many, such, ironclad, which, routes, ambushed, vary,
# Nearest to he: it, they, she, who, there, guang, abendana, mousetrap,
# Nearest to th: paddington, akira, discouraged, submerged, hingis, quote, gated, endosymbiont,
# Nearest to four: five, six, eight, seven, three, nine, zero, two,
# Nearest to may: can, will, would, must, could, cannot, dispel, prev,
# Nearest to called: expiration, namespaces, considered, pickett, airspace, clowning, tug, fib,
# Nearest to most: more, some, many, unprecedented, commentators, miscible, vast, bpm,
# Nearest to no: there, cypriots, ismail, monotheist, psychometric, ramesh, prologue, celebrities,
# Nearest to state: light, unparalleled, princeton, espn, steamship, akc, activating, perilous,
# Nearest to an: versus, shore, indulgence, ende, succumb, interpreted, supervisory, momenta,
# Nearest to for: by, amphibians, of, lymphoid, when, on, jog, cameraman,
# Nearest to they: he, we, there, it, who, you, not, renegades,
# Nearest to will: may, would, can, could, must, to, obeys, should,
# Nearest to up: greatly, skirt, pavel, vanquish, mel, nmi, ting, serena,
# Average loss at step 22000: 3.545745
# Average loss at step 24000: 3.541389
# Average loss at step 26000: 3.577279
# Average loss at step 28000: 3.553969
# Average loss at step 30000: 3.500268
# Nearest to that: which, however, but, who, what, this, impressionists, laundry,
# Nearest to and: or, but, while, who, s, when, to, including,
# Nearest to these: some, many, such, several, ironclad, which, those, their,
# Nearest to he: it, she, they, who, there, but, abendana, we,
# Nearest to th: paddington, akira, seven, rd, discouraged, hingis, gated, endosymbiont,
# Nearest to four: five, seven, three, eight, six, nine, zero, two,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to called: expiration, considered, tug, airspace, linebackers, used, fib, jackson,
# Nearest to most: more, unprecedented, some, miscible, many, affectionately, less, honours,
# Nearest to no: a, there, another, karenga, only, ramesh, cypriots, blasts,
# Nearest to state: light, unparalleled, espn, akc, princeton, unusual, binghamton, steamships,
# Nearest to an: brainiac, ende, the, shore, indulgence, its, succumb, tonnes,
# Nearest to for: when, lymphoid, to, amphibians, after, thracian, and, toward,
# Nearest to they: he, we, there, you, who, it, not, i,
# Nearest to will: would, can, could, may, must, should, might, to,
# Nearest to up: greatly, skirt, look, steamed, him, broz, reputed, nmi,
# Average loss at step 32000: 3.487938
# Average loss at step 34000: 3.485930
# Average loss at step 36000: 3.446599
# Average loss at step 38000: 3.426847
# Average loss at step 40000: 3.449929
# Nearest to that: which, however, what, this, it, mountaineers, but, impressionists,
# Nearest to and: or, but, farmhouse, including, while, when, witold, hrvatska,
# Nearest to these: many, some, several, all, those, their, are, such,
# Nearest to he: it, she, they, there, who, we, abendana, schematics,
# Nearest to th: paddington, rd, akira, roundly, endosymbiont, explosively, caravans, crests,
# Nearest to four: five, eight, seven, six, three, nine, zero, two,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to called: used, considered, airspace, fib, pickett, tug, namespaces, spoiling,
# Nearest to most: more, many, less, some, unprecedented, miscible, affectionately, commentators,
# Nearest to no: only, karenga, there, ramesh, ke, igg, cypriots, another,
# Nearest to state: light, unparalleled, espn, dodger, akc, steamship, fluorite, unrealistic,
# Nearest to an: the, its, timurid, indulgence, ende, brainiac, fabricated, cdots,
# Nearest to for: amphibians, when, lymphoid, if, stasi, or, spinners, like,
# Nearest to they: we, there, he, you, it, she, not, who,
# Nearest to will: would, can, could, may, must, should, cannot, might,
# Nearest to up: out, him, skirt, greatly, them, look, back, steamed,
# Average loss at step 42000: 3.372820
# Average loss at step 44000: 3.456625
# Average loss at step 46000: 3.427101
# Average loss at step 48000: 3.399247
# Average loss at step 50000: 3.491640
# Nearest to that: which, however, what, this, planckian, but, semmelweis, schechter,
# Nearest to and: or, while, including, but, however, marino, although, alignments,
# Nearest to these: many, some, several, all, those, such, were, their,
# Nearest to he: she, it, they, who, there, finally, originally, abendana,
# Nearest to th: paddington, rd, akira, four, roundly, endosymbiont, twentieth, caravans,
# Nearest to four: five, seven, eight, three, six, nine, two, zero,
# Nearest to may: can, would, could, must, will, should, might, cannot,
# Nearest to called: used, considered, known, referred, fib, named, airspace, pickett,
# Nearest to most: more, many, some, several, among, less, miscible, affectionately,
# Nearest to no: ke, ramesh, only, karenga, duplications, igg, kajang, any,
# Nearest to state: espn, unparalleled, akc, light, binghamton, unrealistic, balinese, city,
# Nearest to an: tropics, indulgence, interpreted, ende, deshima, leech, cervantes, packers,
# Nearest to for: after, thracian, including, amphibians, during, when, in, while,
# Nearest to they: we, there, he, you, she, it, who, i,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to up: him, out, back, off, them, kindling, greatly, broz,
# Average loss at step 52000: 3.406206
# Average loss at step 54000: 3.257996
# Average loss at step 56000: 3.401780
# Average loss at step 58000: 3.368211
# Average loss at step 60000: 3.422653
# Nearest to that: which, however, what, schechter, henotheism, tagged, aloof, estampie,
# Nearest to and: or, but, than, among, while, farmhouse, against, when,
# Nearest to these: many, several, some, those, such, all, their, various,
# Nearest to he: she, it, they, who, there, finally, abendana, we,
# Nearest to th: rd, paddington, akira, endosymbiont, bc, twentieth, roundly, caravans,
# Nearest to four: six, seven, three, five, eight, nine, two, zero,
# Nearest to may: can, could, would, must, should, will, might, cannot,
# Nearest to called: used, known, considered, referred, named, fib, schoolteacher, tektites,
# Nearest to most: more, many, some, encore, reflex, miscible, imaginations, less,
# Nearest to no: any, another, ke, duplications, karenga, igg, falun, ud,
# Nearest to state: akc, rpgs, states, light, espn, pattern, piecewise, cyberpunk,
# Nearest to an: indulgence, tropics, posits, devoiced, deshima, juxtaposition, the, cliques,
# Nearest to for: without, amphibians, lymphoid, by, when, thracian, fangio, reals,
# Nearest to they: we, he, there, you, she, it, who, even,
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to up: him, out, them, off, back, broz, skirt, kindling,
# Average loss at step 62000: 3.418980
# Average loss at step 64000: 3.372094
# Average loss at step 66000: 3.358680
# Average loss at step 68000: 3.335875
# Average loss at step 70000: 3.266811
# Nearest to that: which, however, what, where, this, repeaters, plasmas, dagger,
# Nearest to and: or, including, weber, while, alignments, confines, via, when,
# Nearest to these: many, some, several, those, both, such, they, routes,
# Nearest to he: she, it, they, there, who, soon, finally, eventually,
# Nearest to th: rd, four, paddington, akira, twentieth, endosymbiont, bc, messier,
# Nearest to four: five, six, three, seven, eight, two, nine, one,
# Nearest to may: can, could, would, must, should, might, will, cannot,
# Nearest to called: used, named, considered, tug, known, hyundai, referred, fib,
# Nearest to most: more, many, some, less, miscible, several, unprecedented, carina,
# Nearest to no: any, another, clearinghouse, than, ismail, duplications, karenga, igg,
# Nearest to state: states, akc, rpgs, council, conquest, city, espn, binghamton,
# Nearest to an: tropics, deshima, interpreted, indulgence, insights, posits, headroom, ende,
# Nearest to for: without, after, when, while, lymphoid, amphibians, if, praxis,
# Nearest to they: he, we, there, she, you, it, these, soon,
# Nearest to will: would, could, should, can, may, must, might, cannot,
# Nearest to up: him, out, off, them, back, down, kindling, broz,
# Average loss at step 72000: 3.379168
# Average loss at step 74000: 3.266484
# Average loss at step 76000: 3.305815
# Average loss at step 78000: 3.259385
# Average loss at step 80000: 3.361982
# Nearest to that: which, however, what, where, but, schechter, who, iambic,
# Nearest to and: or, but, while, including, hrvatska, ayyash, however, damn,
# Nearest to these: several, some, those, many, both, they, such, various,
# Nearest to he: she, it, they, who, there, soon, but, eventually,
# Nearest to th: rd, twentieth, akira, paddington, endosymbiont, cryogenics, bc, caravans,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to may: can, could, will, must, should, would, might, cannot,
# Nearest to called: used, known, browski, referred, danville, tug, considered, named,
# Nearest to most: more, less, many, some, regiments, encore, unprecedented, earliest,
# Nearest to no: duplications, any, lionheart, ud, karenga, another, clearinghouse, igg,
# Nearest to state: states, light, city, conquest, rpgs, akc, espn, unrealistic,
# Nearest to an: deshima, another, insights, tropics, timurid, leech, cervantes, the,
# Nearest to for: after, thracian, amphibians, praxis, if, of, lymphoid, good,
# Nearest to they: we, he, you, she, there, it, these, who,
# Nearest to will: would, can, could, must, should, may, cannot, might,
# Nearest to up: him, off, out, down, back, them, kindling, together,
# Average loss at step 82000: 3.390750
# Average loss at step 84000: 3.331484
# Average loss at step 86000: 3.327824
# Average loss at step 88000: 3.160083
# Average loss at step 90000: 3.355035
# Nearest to that: which, what, however, this, where, estampie, dagger, nevertheless,
# Nearest to and: or, but, with, like, relayed, of, farmhouse, damn,
# Nearest to these: several, those, many, some, such, various, their, the,
# Nearest to he: she, it, they, there, who, we, nonsensical, originally,
# Nearest to th: twentieth, rd, paddington, nineteenth, bc, akira, one, six,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Nearest to may: can, could, might, would, should, must, will, cannot,
# Nearest to called: named, referred, used, known, fib, browski, tug, linebackers,
# Nearest to most: many, more, some, less, carina, especially, several, both,
# Nearest to no: any, karenga, duplications, kajang, ke, another, it, ud,
# Nearest to state: states, rpgs, akc, espn, piecewise, light, needs, pattern,
# Nearest to an: deshima, indulgence, ende, posits, another, interpreted, timurid, axels,
# Nearest to for: while, compositional, of, to, without, if, amphibians, after,
# Nearest to they: we, he, you, there, she, it, who, these,
# Nearest to will: would, can, could, must, should, may, cannot, might,
# Nearest to up: out, off, him, down, back, them, together, kindling,
# Average loss at step 92000: 3.357242
# Average loss at step 94000: 3.375579
# Average loss at step 96000: 3.364323
# Average loss at step 98000: 3.372507
# Average loss at step 100000: 3.305305
# Nearest to that: which, however, what, nevertheless, henotheism, this, where, unverified,
# Nearest to and: or, including, but, isadora, in, rp, although, connections,
# Nearest to these: several, many, those, some, such, various, both, they,
# Nearest to he: she, it, they, there, who, finally, soon, we,
# Nearest to th: rd, bc, twentieth, six, one, four, nineteenth, paddington,
# Nearest to four: five, six, seven, three, eight, two, nine, one,
# Nearest to may: can, might, could, would, must, should, will, cannot,
# Nearest to called: named, creates, leonard, known, referred, used, browski, rcs,
# Nearest to most: many, more, some, less, carina, all, because, especially,
# Nearest to no: any, kajang, little, nothing, duplications, another, extractor, igg,
# Nearest to state: states, rpgs, city, akc, council, espn, dodger, neyman,
# Nearest to an: timurid, leech, deshima, headroom, lathes, axels, indulgence, posits,
# Nearest to for: after, while, without, despite, including, when, against, praxis,
# Nearest to they: we, he, there, you, she, these, it, who,
# Nearest to will: would, can, could, must, should, might, cannot, may,
# Nearest to up: off, down, back, him, out, together, broz, nude,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# <hr>
# ## Problem
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                                labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
            print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.614588
# Nearest to this: bam, shipments, cimbri, bner, difference, gmail, technische, bloodstream,
# Average loss at step 2000: 4.559008
# Average loss at step 4000: 3.719455
# Average loss at step 6000: 3.742461
# Average loss at step 8000: 3.598560
# Average loss at step 10000: 3.556331
# Nearest to this: it, which, what, handgun, the, a, its, butlerian,
# Average loss at step 12000: 3.539440
# Average loss at step 14000: 3.356578
# Average loss at step 16000: 3.446197
# Average loss at step 18000: 3.410734
# Average loss at step 20000: 3.331376
# Nearest to this: it, which, that, he, highbury, umayyads, wied, moshe,
# Average loss at step 22000: 3.300368
# Average loss at step 24000: 3.331391
# Average loss at step 26000: 3.259341
# Average loss at step 28000: 3.077665
# Average loss at step 30000: 3.222859
# Nearest to this: it, which, the, what, that, another, a, clip,
# Average loss at step 32000: 3.211988
# Average loss at step 34000: 3.183698
# Average loss at step 36000: 3.216650
# Average loss at step 38000: 3.238335
# Average loss at step 40000: 3.154856
# Nearest to this: the, which, it, hr, a, another, clip, every,
# Average loss at step 42000: 3.135433
# Average loss at step 44000: 3.112616
# Average loss at step 46000: 3.077299
# Average loss at step 48000: 3.080288
# Average loss at step 50000: 3.115412
# Nearest to this: it, another, an, which, renn, santana, some, rove,
# Average loss at step 52000: 2.949057
# Average loss at step 54000: 3.067567
# Average loss at step 56000: 3.049168
# Average loss at step 58000: 3.010765
# Average loss at step 60000: 2.968441
# Nearest to this: which, another, it, the, purges, that, repurchase, bantu,
# Average loss at step 62000: 2.925636
# Average loss at step 64000: 3.021361
# Average loss at step 66000: 3.032221
# Average loss at step 68000: 2.833182
# Average loss at step 70000: 3.000623
# Nearest to this: which, what, it, the, another, she, that, positing,
# Average loss at step 72000: 3.017945
# Average loss at step 74000: 2.994708
# Average loss at step 76000: 2.860208
# Average loss at step 78000: 2.958989
# Average loss at step 80000: 2.924767
# Nearest to this: another, it, daylight, which, what, renn, futurology, stringing,
# Average loss at step 82000: 2.945850
# Average loss at step 84000: 2.917479
# Average loss at step 86000: 2.861765
# Average loss at step 88000: 2.912036
# Average loss at step 90000: 2.890913
# Nearest to this: which, another, it, daylight, the, what, a, ncr,
# Average loss at step 92000: 2.491161
# Average loss at step 94000: 2.593765
# Average loss at step 96000: 2.811023
# Average loss at step 98000: 2.824398
# Average loss at step 100000: 2.917808
# Nearest to this: it, which, daylight, what, another, metallica, kolingba, particular,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# <hr>
